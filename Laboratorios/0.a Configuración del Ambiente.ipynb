# %% [markdown]
# # Aplicaciones en Ciencia de Datos - DATA 1002
# ## Laboratorio 1: Configuración del Ambiente de Programación

# %% [markdown]
# ### 1. Introducción
#
# Python es un lenguaje de programación ampliamente utilizado en las aplicaciones web, el desarrollo de software, la ciencia de datos y el machine learning (ML). Los desarrolladores utilizan Python porque es eficiente y fácil de aprender, además de que se puede ejecutar en muchas plataformas diferentes. El software Python se puede descargar gratis, se integra bien a todos los tipos de sistemas y aumenta la velocidad del desarrollo.
#
# Los beneficios de Python incluyen los siguientes:
#
# - Los desarrolladores pueden leer y comprender fácilmente los programas de Python debido a su sintaxis básica similar a la del inglés.
# - Python permite que los desarrolladores sean más productivos, ya que pueden escribir un programa de Python con menos líneas de código en comparación con muchos otros lenguajes.
# - Python cuenta con una gran biblioteca estándar que contiene códigos reutilizables para casi cualquier tarea. De esta manera, los desarrolladores no tienen que escribir el código desde cero.
# - Los desarrolladores pueden utilizar Python fácilmente con otros lenguajes de programación conocidos, como Java, C y C++.
# - La comunidad activa de Python incluye millones de desarrolladores alrededor del mundo que prestan su apoyo. Si se presenta un problema, puede obtener soporte rápido de la comunidad.
# - Hay muchos recursos útiles disponibles en Internet si desea aprender Python. Por ejemplo, puede encontrar con facilidad videos, tutoriales, documentación y guías para desarrolladores.
# - Python se puede trasladar a través de diferentes sistemas operativos de computadora, como Windows, macOS, Linux y Unix.
#
# ¿Cuáles son las características de Python?
#
# Las características siguientes del lenguaje de programación Python lo hacen único:
#
# - Un lenguaje interpretado: Python es un lenguaje interpretado, lo que significa que ejecuta directamente el código línea por línea. Si existen errores en el código del programa, su ejecución se detiene. Así, los programadores pueden encontrar errores en el código con rapidez.
# - Un lenguaje fácil de utilizar: Python utiliza palabras similares a las del inglés. A diferencia de otros lenguajes de programación, Python no utiliza llaves. En su lugar, utiliza sangría.
# - Un lenguaje tipeado dinámicamente: Los programadores no tienen que anunciar tipos de variables cuando escriben código porque Python los determina en el tiempo de ejecución. Debido a esto, es posible escribir programas de Python con mayor rapidez.
# - Un lenguaje de alto nivel: Python es más cercano a los idiomas humanos que otros lenguajes de programación. Por lo tanto, los programadores no deben preocuparse sobre sus funcionalidades subyacentes, como la arquitectura y la administración de la memoria.
# - Un lenguaje orientado a los objetos: Python considera todo como un objeto, pero también admite otros tipos de programación, como la programación estructurada y la funcional.

# %% [markdown]
# ### 2. Instalación de Python

# %% [markdown]
# #### 2.1 Anaconda
#
# Como se imaginaran, para las clases usaremos Python y es necesario que todos lo tengan instalado al llegar a la primera clase para poder empezar a programar inmediatamente. Hay muchas manera de instalar y/o usar Python, nuestra manera recomendada es mediante Anaconda.
#
# Anaconda es un gestor de paquetes, de entornos y una distribución de Python que contiene una colección de muchos paquetes de código abierto. Esto es una gran ventaja ya que cuando esten trabajando en un proyecto, encontrarán que necesitan muchos paquetes diferentes (numpy, scikit-learn, scipy, pandas por nombrar algunos), con los que una instalación de Anaconda viene preinstalada. Si necesitan paquetes adicionales después de instalar Anaconda, puedes usar el gestor de paquetes de Anaconda, conda, o pip para instalar esos paquetes (no se preocupen, el como hacerlo lo cubriremos en el curso). Adicional, a instalar Python y muchos de los paquetes mas utilizados, Anaconda instala dos de los IDE mas populares de Python: Spyder y Jupyter Notebook.
#
# Un IDE (entorno de desarrollo integrado) es un software que brinda las herramientas que necesitan para escribir, editar, probar y corregir código en un único lugar. Sin ellos tendríamos que escribir y ejecutar el código desde la consola, y nadie quiere eso.
#
#
# ##### 2.1.1 Spyder
#
# Spyder es un IDE de código abierto que utilizan muchos científicos y analistas de datos. Proporciona una experiencia integral de desarrollo con características para el análisis avanzado de datos, su visualización y depuración.

# %% [markdown]
# ![alt text](../Img/Spyder.png)

# %% [markdown]
# También incluye las siguientes características:
#
# - Editor completo de código que admite varios lenguajes
# - Consola interactiva de IPython
# - Depurador básico
# - Posibilidad de explorar variables en el código
# - Posibilidad de visualizar documentación en tiempo real
#
# Spyder es más similar a un interprete de código tradicional, posee un visor de objetos, una consola y un lugar para la edición de código. Se programa mediante scripts y al ser ejecutados sus resultados pueden verse en la consola

# %% [markdown]
# ##### 2.1.2 Jupyter Notebook

# %% [markdown]
# Jupyter Notebook Creado a partir de IPython en 2014 por Fernando Pérez, el proyecto Jupyter soporta entornos de ejecución en varias docenas de lenguajes de programación. El nombre del proyecto Jupyter es una referencia a los tres lenguajes de programación principales soportados por Jupyter, que son Julia, Python y R.

# %% [markdown]
# ![alt text](../Img/Jupyter.png)

# %% [markdown]
# El producto mas reconocible del proyecto Jupyter es el Jupyter Notebook. Este, amplía el enfoque basado en la consola para la computación interactiva en una dirección nueva, proporcionando una aplicación basada en la web adecuada para capturar todo el proceso de computación: desarrollar, documentar y ejecutar el código, así como comunicar los resultados. El Jupyter notebook combina dos componentes:
#
# * **Una aplicación web**: una herramienta basada en el navegador para la creación interactiva de documentos que combinan texto explicativo, matemáticas, cálculos y su salida en medios ricos.
#
# * **Un Notebook**: una representación de todo el contenido visible en la aplicación web, incluidas las entradas y salidas de los cálculos, el texto explicativo, las matemáticas, las imágenes y las representaciones multimedia de los objetos.
#
# Las princiales caracteristicas del Jupyter Notebook, que a nuestro parecer lo hacen superior a los demas IDE y mucho mas amigable para aprender y presentr código, son:
#
# - Edición de código en el navegador, con resaltado automático de sintaxis, sangría y completado/introspección de tabulaciones.
#
# - Capacidad de ejecutar código desde el navegador, con los resultados de los cálculos adjuntos al código que los generó.
#
# - Visualización de los resultados de los cálculos mediante representaciones multimedia enriquecidas, como HTML, LaTeX, PNG, SVG, etc. Por ejemplo, pueden incluirse en línea figuras de calidad de publicación, representadas por la biblioteca matplotlib.
#
# - La edición en el navegador de texto enriquecido mediante el lenguaje de marcado Markdown, que puede proporcionar comentarios para el código, no se limita al texto plano.
#
# - La capacidad de incluir fácilmente la notación matemática dentro de las celdas de Markdown utilizando LaTeX, y renderizada de forma nativa por MathJax.
#
# Dentro de los 2 IDE que se instalan con Anaconda nuestro recomendado y favorito es, ciertamente, Jupyter Notebook. De hecho, esto que estan leyendo fue hecho en un Jupyter Notebook :)

# %% [markdown]
# ##### 2.1.3 Instalación

# %% [markdown]
# 1. Vamos a la página oficial de Anaconda y seleccionamos Download. Por efecto, Anaconda reconoce el sistema operativo que poseemos (sea Windows, ios o Linux) y nos sugiere instalar la ultima versión.
#
# ![alt text](../Img/Anaconda1.png)

# %% [markdown]
# 2. Apenas le demos a Download, se descarga un ejecutable. Una vez termine, le damos click
# ![alt text](../Img/Anaconda2.png)

# %% [markdown]
# 3. Aparecera la siguiente patalla, indicandonos los pasos a seguir para completar la instalación, le damos Next
# ![alt text](../Img/Anaconda3.png)

# %% [markdown]
# 4. Aceptamos los terminos de uso, seleccionado I Agree
# ![alt text](../Img/Anaconda4.png)

# %% [markdown]
# 5. Dejamos por lo que viene por defecto y le damos Next
# ![alt text](../Img/Anaconda5.png)

# %% [markdown]
# 6. Seleccionamos la ubicación donde queremos instalar Anaconda y le damos Next
# ![alt text](../Img/Anaconda6.png)

# %% [markdown]
# 7. Dejamos lo recomendado y registramos Anaconda como nuestra aplicación predeterminada para Python, luego le damos Install
# ![alt text](../Img/Anaconda7.png)

# %% [markdown]
# 8. Esperamos que termine de instalar
# ![alt text](../Img/Anaconda8.png)

# %% [markdown]
# 9. Pueden también instalar VS Code (otro IDE) pero es opcional.
# ![alt text](../Img/Anaconda9.png)

# %% [markdown]
# 10. Listo! Hemos instalado correctamente Anaconda
# ![alt text](../Img/Anaconda10.png)

# %% [markdown]
# #### 2.2 VSCode

# %% [markdown]
# Visual Studio Code, al que conocemos también como VSCode, es un editor de código para programadores gratuito, de código abierto y multiplataforma. Está desarrollado por Microsoft, una compañía con una dilatada experiencia en la creación de IDEs (entornos de desarrollo integrados), que ha conseguido plasmar su larga tradición en el sector para ofrecer una herramienta ligera y práctica que la comunidad ha adoptado en masa.
#
# Aunque su nombre viene de otra de las herramientas creadas por la propia Microsoft, IDE Visual Studio, VSCode es en realidad una aplicación independiente y desarrollada bajo una base de código distinta y en tecnologías totalmente dispares. Además, mientras que Visual Studio está preparado para desarrollar especialmente con los lenguajes y tecnologías exclusivos de Microsoft, VSCode es capaz de adaptarse a cualquier lenguaje de programación que nos podamos imaginar.
#
# Dentro de sus principales caracteristicas se encuentran:
# * Interfaz intuitiva y altamente personalizable
# * Soporte integrado para múltiples lenguajes de programación
# * Cuenta con un sistema de extensiones para ampliar funcionalidades
# * Permite control de versiones con integración Git nativa
# * Depuración eficiente con herramientas integradas
#
# Debido a su versatilidad y facilidad de instalación, VSCode es lo que recomendamos en el curso para trabajar.

# %% [markdown]
# ##### 2.2.1 Instalación

# %% [markdown]
# 1. Vamos a la página oficinal de Visual Studio Code y justo en la pagina principal nos da la opción de descargar.
# ![alt text](../Img/VSCode1.png)

# %% [markdown]
# 2. Dependiendo del sistema operativo es ligeramente diferente.
# * Si tienen Windows, el proceso es similar al de Anaconda: Abrir el instalador y seguir los pasos.
# * Si se tiene Mac es simplemente arrastrar el programa a la carpeta de aplicaciones.
# ![alt text](../Img/VSCode2.png)

# %% [markdown]
# 3. A diferencia de Anaconda, que es una distribución de Python, para poder usar python en VSCode es necesario descargar tambieén Python y la respectiva extensión.
# * Para descargar python, vamos a la página oficial y le damos click a descargar:
# ![alt text](../Img/Python.png)

# %% [markdown]
# 4. Una vez instalado Python debemos instalar las extensiones de Python y Jupyter para poder usarlo dentro de Visual Studio. para esto abrimos Visual Studio y vamos a la tienda de extensiones que deberá estar en la barra lateral
#
# ![alt text](../Img/Extensiones.png)

# %% [markdown]
# 5. Buscamos Python e instalamos la version oficial, aquella que diga Microsoft y tenga un chulito azul de verificación
# ![alt text](../Img/PythonVS.png)

# %% [markdown]
# 6. Para Jupyter hacemos lo mismo, en la tienda de extensiones buscamos Jupyter.
# ![alt text](../Img/JupyterVS.png)

# %% [markdown]
# 7. Con esto ya podemos empezar a programar!

# %% [markdown]
# #### 2.3 Google Colab

# %% [markdown]
# Si prefieren no instalar nada en su computador, una alternativa a esto es hacer uso de Google Colab.
#
# Colab, también conocido como "Colaboratory", permite programar y ejecutar Python en el navegador con las siguientes ventajas:
#
# * No requiere configuración
# * Acceso a GPUs sin coste adicional
# * Permite compartir contenido fácilmente
#
# Para usarlo solo deben dirigirse a la página de Colab y empezar a utilizarlo. Al abrirlo se darán cuenta que luce y funciona igual que un Jupyter Notebook, pero con la ventaja de no tener que instalar nada.
#
# ![alt text](../Img/Colab.png)

# %% [markdown]
# ### 3. Ambiente Virtual
#
# Las aplicaciones en Python usualmente hacen uso de paquetes y módulos que no forman parte de la librería estándar. Las aplicaciones a veces necesitan una versión específica de una librería, debido a que dicha aplicación requiere que un bug particular haya sido solucionado o bien la aplicación ha sido escrita usando una versión obsoleta de la interfaz de la librería.
#
# Esto significa que tal vez no sea posible para una instalación de Python cumplir los requerimientos de todas las aplicaciones. Si la aplicación A necesita la versión 1.0 de un módulo particular y la aplicación B necesita la versión 2.0, entonces los requerimientos entran en conflicto e instalar la versión 1.0 o 2.0 dejará una de las aplicaciones sin funcionar.
#
# La solución a este problema es crear un entorno virtual. En términos simples los entornos virtales podemos definirlos como espacio aislado donde seremos capaces de gestionar cada una de las dependencias necesarias para cada proyecto. Estos entornos son autónomos e individuales. Es decir, un entorno para cada uno de los proyectos.
#
# Cada entorno virtual contiene su propia instalación de Python y las bibliotecas o paquetes necesarios para que el proyecto pueda funcionar. Esto ayuda a evitar conflictos entre versiones de bibliotecas y asegura que un proyecto tenga todas las dependencias correctas, independientemente de las de otros proyectos.
#
# Podemos ver a los entornos como pequeñas burbujas, donde en cada una de ellas está todo los necesario para que un proyecto en particular pueda funcionar. Esto incluye una versión de Python, librerías, módulos, Frameworks, entre otros.
#
# Trabajar con entornos virtuales nos trea varias ventajas:
# * **Aislamiento de proyectos**: Los entornos virtuales permiten aislamiento completo entre proyectos. Cada proyecto puede tener su propia versión de Python y sus propias dependencias sin interferir con otros proyectos.
#
# * **Portabilidad**: Puedes compartir un archivo de requisitos con otros desarrolladores para que puedan crear el mismo entorno virtual en sus sistemas, lo que garantiza que todos trabajen en el mismo entorno.
#
# * **Gestión de dependencias**: Puedes instalar y gestionar fácilmente las bibliotecas y paquetes requeridos para un proyecto específico dentro de su propio entorno virtual. Esto garantiza que todas las dependencias se mantengan bajo control y se puedan replicar fácilmente.
#
# **Por esto para el curso siempre recomendaremos trabajar sobre ambientes virtuales, de manera que tengamos total control sobre lo que instalamos y lo que no, ademas que es una buena practica de reproducibilidad como veremos en un par de semanas.**
#
# La manera mas sencilla de usar un ambiente virtual es mediante VSCode, que podemos crearlo directamente en la pantalla al seleccionar un kernel para nuestro notebook. Si estamos usando Anaconda, el proceso se alarga un poco mas.
